# %% [markdown]
# <a href="https://colab.research.google.com/github/andersongiulliano/curso_extensao_pandas/blob/main/PrimeiroExemploEmPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Primeiro exemplo de manipulação de dados usando Python Pandas**
#
# **Manutenção de veículos da UFRN**
#
# Autor: Anderson Giulliano Silva Gomes
#
# Data: 06 de fevereiro de 2023

# %%
# importando biblioteca pandas no python

import pandas as pd

man_df = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/man_veic.xlsx")

# %%
display(man_df)
# Out:
#       Ordem de Servico                  DataOS       Marca             Modelo  \
# 0               4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 1               4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 2               4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 3               4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 4               5355.0 2022-09-06 14:25:01.390        FIAT  DOBLO ESSENCE 1.8
# ...                ...                     ...         ...                ...
# 9928            5436.0 2022-09-28 16:15:22.750  VOLKSWAGEN    AMAROK CD 4X4 S
# 9929            5436.0 2022-09-28 16:15:22.750  VOLKSWAGEN    AMAROK CD 4X4 S
# 9930            5436.0 2022-09-28 16:15:22.750  VOLKSWAGEN    AMAROK CD 4X4 S
# 9931            5436.0 2022-09-28 16:15:22.750  VOLKSWAGEN    AMAROK CD 4X4 S
# 9932            5436.0 2022-09-28 16:15:22.750  VOLKSWAGEN    AMAROK CD 4X4 S
#
#          Placa      Cidade                      Unidade    Situacao  \
# 0     QGD-3761       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE  FINALIZADA
# 1     QGD-3761       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE      NEGADA
# 2     QGD-3761       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE      NEGADA
# 3     QGD-3761  PARNAMIRIM  CENTRO DE CIÊNCIAS DA SAÚDE      NEGADA
# 4     OWD-8786       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE  FINALIZADA
# ...        ...         ...                          ...         ...
# 9928  QGE-7950       NATAL        CENTRO DE BIOCIÊNCIAS      NEGADA
# 9929  QGE-7950       NATAL        CENTRO DE BIOCIÊNCIAS      NEGADA
# 9930  QGE-7950       NATAL        CENTRO DE BIOCIÊNCIAS      NEGADA
# 9931  QGE-7950       NATAL        CENTRO DE BIOCIÊNCIAS      NEGADA
# 9932  QGE-7950       NATAL        CENTRO DE BIOCIÊNCIAS      NEGADA
#
#                                    Oficina  ValorPecas  ValorMaoDeObra  \
# 0                           LIMPAUTO NATAL       47.15            35.0
# 1               R E T SERVICOS AUTOMOTIVOS       52.90            45.0
# 2           TDR CENTRO AUTOMOTIVO DE PECAS       50.50            40.0
# 3               R7 DIESEL PECAS E SERVICOS        0.00             0.0
# 4               R E T SERVICOS AUTOMOTIVOS      415.41           180.0
# ...                                    ...         ...             ...
# 9928                          DIVE GENESIS        0.00             0.0
# 9929                             DIESELMEC        0.00             0.0
# 9930  DCP DISTRIBUICAO E COMERCIO DE PECAS        0.00             0.0
# 9931              DANKAR CENTRO AUTOMOTIVO        0.00             0.0
# 9932                      Cyro Cavalcanti         0.00             0.0
#
#       ValorTotal  AbertoPor
# 0          82.15        NaN
# 1          97.90        NaN
# 2          90.50        NaN
# 3           0.00        NaN
# 4         595.41        NaN
# ...          ...        ...
# 9928        0.00        NaN
# 9929        0.00        NaN
# 9930        0.00        NaN
# 9931        0.00        NaN
# 9932        0.00        NaN
#
# [9933 rows x 13 columns]

# %%
display(man_df.head(15))
# Out:
#     Ordem de Servico                  DataOS       Marca             Modelo  \
# 0             4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 1             4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 2             4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 3             4554.0 2022-03-24 15:14:57.400        FIAT              LINEA
# 4             5355.0 2022-09-06 14:25:01.390        FIAT  DOBLO ESSENCE 1.8
# 5             5355.0 2022-09-06 14:25:01.390        FIAT  DOBLO ESSENCE 1.8
# 6             5355.0 2022-09-06 14:25:01.390        FIAT  DOBLO ESSENCE 1.8
# 7             5613.0 2022-11-22 09:35:04.770        FIAT              LINEA
# 8             5613.0 2022-11-22 09:35:04.770        FIAT              LINEA
# 9             5613.0 2022-11-22 09:35:04.770        FIAT              LINEA
# 10            5613.0 2022-11-22 09:35:04.770        FIAT              LINEA
# 11            4920.0 2022-06-02 10:27:26.707   CHEVROLET           SPIN 1.8
# 12            4920.0 2022-06-02 10:27:26.707   CHEVROLET           SPIN 1.8
# 13            4920.0 2022-06-02 10:27:26.707   CHEVROLET           SPIN 1.8
# 14            5138.0 2022-07-26 11:54:49.697  VOLKSWAGEN                GOL
#
#        Placa      Cidade                                     Unidade  \
# 0   QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 1   QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 2   QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 3   QGD-3761  PARNAMIRIM                 CENTRO DE CIÊNCIAS DA SAÚDE
# 4   OWD-8786       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 5   OWD-8786       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 6   OWD-8786  PARNAMIRIM                 CENTRO DE CIÊNCIAS DA SAÚDE
# 7   QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 8   QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 9   QGD-3761  PARNAMIRIM                 CENTRO DE CIÊNCIAS DA SAÚDE
# 10  QGD-3761       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 11  QGE-8987       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 12  QGE-8987       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 13  QGE-8987  PARNAMIRIM  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 14  JKO-7291       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#       Situacao                         Oficina  ValorPecas  ValorMaoDeObra  \
# 0   FINALIZADA                  LIMPAUTO NATAL       47.15            35.0
# 1       NEGADA      R E T SERVICOS AUTOMOTIVOS       52.90            45.0
# 2       NEGADA  TDR CENTRO AUTOMOTIVO DE PECAS       50.50            40.0
# 3       NEGADA      R7 DIESEL PECAS E SERVICOS        0.00             0.0
# 4   FINALIZADA      R E T SERVICOS AUTOMOTIVOS      415.41           180.0
# 5       NEGADA  TDR CENTRO AUTOMOTIVO DE PECAS      484.00           240.0
# 6       NEGADA      R7 DIESEL PECAS E SERVICOS      515.41           200.0
# 7   FINALIZADA                  LIMPAUTO NATAL      340.00             0.0
# 8       NEGADA  TDR CENTRO AUTOMOTIVO DE PECAS      390.50            50.0
# 9       NEGADA      R7 DIESEL PECAS E SERVICOS      408.39             0.0
# 10      NEGADA      R E T SERVICOS AUTOMOTIVOS        0.00             0.0
# 11  FINALIZADA  TDR CENTRO AUTOMOTIVO DE PECAS       62.00           150.0
# 12      NEGADA      R E T SERVICOS AUTOMOTIVOS       54.00           180.0
# 13      NEGADA      R7 DIESEL PECAS E SERVICOS       60.00           180.0
# 14  FINALIZADA                  LIMPAUTO NATAL        0.00           400.0
#
#     ValorTotal  AbertoPor
# 0        82.15        NaN
# 1        97.90        NaN
# 2        90.50        NaN
# 3         0.00        NaN
# 4       595.41        NaN
# 5       724.00        NaN
# 6       715.41        NaN
# 7       340.00        NaN
# 8       440.50        NaN
# 9       408.39        NaN
# 10        0.00        NaN
# 11      212.00        NaN
# 12      234.00        NaN
# 13      240.00        NaN
# 14      400.00        NaN

# %%
# Comandos Dataframe.shape e Dataframe.describe()

print(man_df.describe())
# Out:
#        Ordem de Servico    ValorPecas  ValorMaoDeObra    ValorTotal  AbertoPor
# count       9933.000000   9933.000000     9933.000000   9933.000000        0.0
# mean        5118.990537    352.427344      255.173092    607.600436        NaN
# std          372.474689   1177.163854      891.082707   1588.121660        NaN
# min         3679.000000      0.000000        0.000000      0.000000        NaN
# 25%         4791.000000      0.000000        0.000000      0.000000        NaN
# 50%         5140.000000      0.000000        0.000000      0.000000        NaN
# 75%         5455.000000      7.500000      120.000000    431.000000        NaN
# max         5757.000000  39000.000000    22680.000000  39000.000000        NaN

# %%
print(man_df.shape)
# Out:
# (9933, 13)

# %%
print(man_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9933 entries, 0 to 9932
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ordem de Servico  9933 non-null   float64
#  1   DataOS            9933 non-null   datetime64[ns]
#  2   Marca             9933 non-null   object
#  3   Modelo            9933 non-null   object
#  4   Placa             9933 non-null   object
#  5   Cidade            9933 non-null   object
#  6   Unidade           9933 non-null   object
#  7   Situacao          9933 non-null   object
#  8   Oficina           9933 non-null   object
#  9   ValorPecas        9933 non-null   float64
#  10  ValorMaoDeObra    9933 non-null   float64
#  11  ValorTotal        9933 non-null   float64
#  12  AbertoPor         0 non-null      float64
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1008.9+ KB
# None

# %%
display(man_df['ValorPecas'])
# Out:
# 0        47.15
# 1        52.90
# 2        50.50
# 3         0.00
# 4       415.41
#          ...
# 9928      0.00
# 9929      0.00
# 9930      0.00
# 9931      0.00
# 9932      0.00
# Name: ValorPecas, Length: 9933, dtype: float64

# %%
display(man_df['ValorMaoDeObra'])
# Out:
# 0        35.0
# 1        45.0
# 2        40.0
# 3         0.0
# 4       180.0
#         ...
# 9928      0.0
# 9929      0.0
# 9930      0.0
# 9931      0.0
# 9932      0.0
# Name: ValorMaoDeObra, Length: 9933, dtype: float64

# %%
display(man_df['Situacao'])
# Out:
# 0       FINALIZADA
# 1           NEGADA
# 2           NEGADA
# 3           NEGADA
# 4       FINALIZADA
#            ...
# 9928        NEGADA
# 9929        NEGADA
# 9930        NEGADA
# 9931        NEGADA
# 9932        NEGADA
# Name: Situacao, Length: 9933, dtype: object

# %%
man_df = man_df[['Ordem de Servico','Cidade','Unidade','Oficina','Situacao','ValorPecas','ValorMaoDeObra']]
display(man_df)
# Out:
#       Ordem de Servico      Cidade                      Unidade  \
# 0               4554.0       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE
# 1               4554.0       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE
# 2               4554.0       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE
# 3               4554.0  PARNAMIRIM  CENTRO DE CIÊNCIAS DA SAÚDE
# 4               5355.0       NATAL  CENTRO DE CIÊNCIAS DA SAÚDE
# ...                ...         ...                          ...
# 9928            5436.0       NATAL        CENTRO DE BIOCIÊNCIAS
# 9929            5436.0       NATAL        CENTRO DE BIOCIÊNCIAS
# 9930            5436.0       NATAL        CENTRO DE BIOCIÊNCIAS
# 9931            5436.0       NATAL        CENTRO DE BIOCIÊNCIAS
# 9932            5436.0       NATAL        CENTRO DE BIOCIÊNCIAS
#
#                                    Oficina    Situacao  ValorPecas  \
# 0                           LIMPAUTO NATAL  FINALIZADA       47.15
# 1               R E T SERVICOS AUTOMOTIVOS      NEGADA       52.90
# 2           TDR CENTRO AUTOMOTIVO DE PECAS      NEGADA       50.50
# 3               R7 DIESEL PECAS E SERVICOS      NEGADA        0.00
# 4               R E T SERVICOS AUTOMOTIVOS  FINALIZADA      415.41
# ...                                    ...         ...         ...
# 9928                          DIVE GENESIS      NEGADA        0.00
# 9929                             DIESELMEC      NEGADA        0.00
# 9930  DCP DISTRIBUICAO E COMERCIO DE PECAS      NEGADA        0.00
# 9931              DANKAR CENTRO AUTOMOTIVO      NEGADA        0.00
# 9932                      Cyro Cavalcanti       NEGADA        0.00
#
#       ValorMaoDeObra
# 0               35.0
# 1               45.0
# 2               40.0
# 3                0.0
# 4              180.0
# ...              ...
# 9928             0.0
# 9929             0.0
# 9930             0.0
# 9931             0.0
# 9932             0.0
#
# [9933 rows x 7 columns]

# %%
display(man_df.loc[3])
# Out:
# Ordem de Servico                         4554.0
# Cidade                               PARNAMIRIM
# Unidade             CENTRO DE CIÊNCIAS DA SAÚDE
# Oficina              R7 DIESEL PECAS E SERVICOS
# Situacao                                 NEGADA
# ValorPecas                                  0.0
# ValorMaoDeObra                              0.0
# Name: 3, dtype: object

# %%
#Exibir da 10a. linha até a 20a.linha
display(man_df.loc[9:19])
# Out:
#     Ordem de Servico      Cidade                                     Unidade  \
# 9             5613.0  PARNAMIRIM                 CENTRO DE CIÊNCIAS DA SAÚDE
# 10            5613.0       NATAL                 CENTRO DE CIÊNCIAS DA SAÚDE
# 11            4920.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 12            4920.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 13            4920.0  PARNAMIRIM  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 14            5138.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 15            5138.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 16            5138.0  PARNAMIRIM  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 17            5138.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 18            5679.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 19            5679.0       NATAL  CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
#
#                            Oficina    Situacao  ValorPecas  ValorMaoDeObra
# 9       R7 DIESEL PECAS E SERVICOS      NEGADA      408.39             0.0
# 10      R E T SERVICOS AUTOMOTIVOS      NEGADA        0.00             0.0
# 11  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       62.00           150.0
# 12      R E T SERVICOS AUTOMOTIVOS      NEGADA       54.00           180.0
# 13      R7 DIESEL PECAS E SERVICOS      NEGADA       60.00           180.0
# 14                  LIMPAUTO NATAL  FINALIZADA        0.00           400.0
# 15      R E T SERVICOS AUTOMOTIVOS      NEGADA        0.00           480.0
# 16      R7 DIESEL PECAS E SERVICOS      NEGADA        0.00             0.0
# 17  TDR CENTRO AUTOMOTIVO DE PECAS      NEGADA        0.00           560.0
# 18      R E T SERVICOS AUTOMOTIVOS  FINALIZADA        6.00           500.0
# 19  TDR CENTRO AUTOMOTIVO DE PECAS      NEGADA        8.00           560.0

# %%
# Criar um dataframe finalizadas_df contendo 
# apenas linhas com situação FINALIZADA e exibir na tela
finalizadas_df = man_df.loc[man_df['Situacao'] == 'FINALIZADA']
display(finalizadas_df)
# Out:
#       Ordem de Servico      Cidade  \
# 0               4554.0       NATAL
# 4               5355.0       NATAL
# 7               5613.0       NATAL
# 11              4920.0       NATAL
# 14              5138.0       NATAL
# ...                ...         ...
# 9827            4469.0  PARNAMIRIM
# 9830            4546.0       NATAL
# 9834            5004.0  PARNAMIRIM
# 9838            5067.0       NATAL
# 9842            5239.0       NATAL
#
#                                          Unidade  \
# 0                    CENTRO DE CIÊNCIAS DA SAÚDE
# 4                    CENTRO DE CIÊNCIAS DA SAÚDE
# 7                    CENTRO DE CIÊNCIAS DA SAÚDE
# 11    CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# 14    CENTRO DE CIÊNCIAS HUMANAS, LETRAS E ARTES
# ...                                          ...
# 9827   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA
# 9830   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA
# 9834   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA
# 9838   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA
# 9842   DEPARTAMENTO DE OCEANOGRAFIA E LIMNOLOGIA
#
#                              Oficina    Situacao  ValorPecas  ValorMaoDeObra
# 0                     LIMPAUTO NATAL  FINALIZADA       47.15           35.00
# 4         R E T SERVICOS AUTOMOTIVOS  FINALIZADA      415.41          180.00
# 7                     LIMPAUTO NATAL  FINALIZADA      340.00            0.00
# 11    TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       62.00          150.00
# 14                    LIMPAUTO NATAL  FINALIZADA        0.00          400.00
# ...                              ...         ...         ...             ...
# 9827      R7 DIESEL PECAS E SERVICOS  FINALIZADA        0.00         1233.33
# 9830              CENTRAL AUTO PEÇAS  FINALIZADA      350.00            0.00
# 9834               PAIZAO ACESSORIOS  FINALIZADA      535.60          200.00
# 9838         AUTO ELÉTRICA FELIPECAS  FINALIZADA      300.00          263.00
# 9842                  HC PNEUS NATAL  FINALIZADA      984.00           49.00
#
# [1165 rows x 7 columns]

# %%
pecas_max = (finalizadas_df['ValorPecas'].max())
print('A maior nota fiscal de peças tem o valor de R$ {}'.format(pecas_max))

servico_max = (finalizadas_df['ValorMaoDeObra'].max())
print('A maior nota fiscal de serviços tem o valor de R$ {}'.format(servico_max))
# Out:
# A maior nota fiscal de peças tem o valor de R$ 10614.0
# A maior nota fiscal de serviços tem o valor de R$ 14300.0

# %%
#DataFrame.loc[] com múltiplas condições para filtragem
#Quais são os valores de peças e serviços que a unidade Sup. de Infraestrutura fez na oficina TDR CENTRO AUTOMOTIVO DE PECAS
#ordenado do menor valor de venda para o maior


sin_df = finalizadas_df.loc[(finalizadas_df['Unidade'] == 'SUPERINTENDÊNCIA DE INFRAESTRUTURA') & (finalizadas_df['Oficina'] == 'TDR CENTRO AUTOMOTIVO DE PECAS')]
display(sin_df.sort_values(by='ValorPecas'))
# Out:
#       Ordem de Servico Cidade                             Unidade  \
# 243             5447.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 350             5195.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 7793            5445.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 2981            4625.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8219            4583.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5847            4584.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8220            4586.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8344            4878.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8315            4689.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 473             4763.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5781            4879.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 2443            5446.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5822            4492.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8049            5124.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5826            4521.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5669            5331.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8099            5176.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 425             4614.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5563            5448.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 276             4917.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 2723            4874.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 8014            5010.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 5787            4890.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 268             4880.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 7765            5330.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
# 2588            5177.0  NATAL  SUPERINTENDÊNCIA DE INFRAESTRUTURA
#
#                              Oficina    Situacao  ValorPecas  ValorMaoDeObra
# 243   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA         0.0           350.0
# 350   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA         0.0           120.0
# 7793  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA         0.0          1330.0
# 2981  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA         0.0           240.0
# 8219  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA        90.0            50.0
# 5847  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       103.0            40.0
# 8220  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       106.0            50.0
# 8344  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       184.0          1970.0
# 8315  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       295.0            50.0
# 473   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       353.0           120.0
# 5781  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       536.0          2150.0
# 2443  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       545.0           130.0
# 5822  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       584.0            60.0
# 8049  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       753.0            70.0
# 5826  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA       834.0           120.0
# 5669  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1005.0           100.0
# 8099  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1008.0           180.0
# 425   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1504.0           160.0
# 5563  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1530.0           980.0
# 276   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1643.0           280.0
# 2723  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      1998.0           320.0
# 8014  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      2317.0          1790.0
# 5787  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      2661.0           150.0
# 268   TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      3180.0          2630.0
# 7765  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      3350.0             0.0
# 2588  TDR CENTRO AUTOMOTIVO DE PECAS  FINALIZADA      6250.0           550.0

# %%
# Qual a média de gastos com peças em Natal e Parnamirim nos veiculos da PRÓ-REITORIA DE ADMINISTRAÇÃO (PROAD)?

#PERGUNTAR AO PROFESSOR SOBRE ERRO NO PRINT QUANDO NÃO SE COLOCA O FLOAT

gastos_proad = float(finalizadas_df.loc[(finalizadas_df['Unidade'] == 'PRÓ-REITORIA DE ADMINISTRAÇÃO (PROAD)') & (finalizadas_df['Cidade'] == "NATAL") | ((finalizadas_df['Cidade'] == "PARNAMIRIM") ), ['ValorPecas']].mean())

display(gastos_proad)

print(f'A média de gastos com peças pela unidade PROAD foi de R$ {gastos_proad:.2f}')
# Out:
# 823.2988848263254
# A média de gastos com peças pela unidade PROAD foi de R$ 823.30

# %%
# Qual a média de gastos com peças em Natal e Parnamirim nos veiculos da PRÓ-REITORIA DE ADMINISTRAÇÃO (PROAD)?

# deu diferente do método anterior --- PERGUNTAR AO PROFESSOR

gastos_proad2= float(finalizadas_df.loc[(finalizadas_df['Unidade'] == 'PRÓ-REITORIA DE ADMINISTRAÇÃO (PROAD)') & (finalizadas_df['Cidade'].isin(["NATAL","PARNAMIRIM"])), ['ValorPecas']].mean())

display(gastos_proad2)
# Out:
# 772.9832857142858

# %%
# Como mostrar média de valor de venda POR COMBUSTÍVEL Brasil todo?
media_por_combustivel_df = ca_df[['Produto', 'Valor de Venda']].groupby(by='Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
#Quero adicionar uma coluna de valor booleano no combustiveis_df
# chamada "Ativo" que, por padrão, vai ser True para 
# TODAS as linhas
combustiveis_df['Ativo'] = True
print(combustiveis_df.info())
display(combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
#  15  Bandeira           168409 non-null  object
#  16  Ativo              168409 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(2), object(13)
# memory usage: 20.7+ MB
# None
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira  Ativo
# 0              NaN        R$ / litro  VIBRA ENERGIA   True
# 1              NaN        R$ / litro  VIBRA ENERGIA   True
# 2              NaN        R$ / litro  VIBRA ENERGIA   True
# 3              NaN        R$ / litro  VIBRA ENERGIA   True
# 4              NaN        R$ / litro  VIBRA ENERGIA   True

# %%
# Exportar para Excel o dataframe com etanol em Indaiatuba....
etanol_indaiatuba_df.to_excel('etanol_indaiatuba.xlsx', sheet_name='Etanol em Indaiatuba', index='FALSE')
